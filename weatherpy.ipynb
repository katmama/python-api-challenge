# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
url = "https://api.openweathermap.org/data/2.5/weather?&appid=0c00b6fe601c369bc6e889e5f58a1e44&units=imperial"

# %%
#Initiate counter for city number below
number = 1

#Lists for holding required items
city_name = []
lat = []
lng = []
temp = []
humid = []
clouds = []
wind = []

#Loop through each city, extract required items, and print result
print('------------------------------')
print('Start of Records')
print('------------------------------')

for city in cities:
    try:
        city_data = (requests.get(url + '&q=' + city)).json()
        city_name.append(city_data['name'])
        lat.append(city_data['coord']['lat'])
        lng.append(city_data['coord']['lon'])
        temp.append(city_data['main']['temp'])
        humid.append(city_data['main']['humidity'])
        clouds.append(city_data['clouds']['all'])
        wind.append(city_data['wind']['speed'])
        print(f'City number {number} of {len(cities)} complete. | Added {city}')
        number = number + 1
    
    except KeyError:
        print(f'Missing data in city number {number} of {len(cities)}. | Skipping {city}')
        number = number + 1
        
print('------------------------------')
print('End of Records')
print('------------------------------')
# Out:
# ------------------------------
# Start of Records
# ------------------------------
# City number 1 of 627 complete. | Added iqaluit
# City number 2 of 627 complete. | Added albany
# City number 3 of 627 complete. | Added saint-pierre
# City number 4 of 627 complete. | Added port alfred
# City number 5 of 627 complete. | Added luanda
# City number 6 of 627 complete. | Added norman wells
# City number 7 of 627 complete. | Added east london
# Missing data in city number 8 of 627. | Skipping barentsburg
# City number 9 of 627 complete. | Added punta arenas
# City number 10 of 627 complete. | Added usinsk
# City number 11 of 627 complete. | Added carnarvon
# City number 12 of 627 complete. | Added port hedland
# City number 13 of 627 complete. | Added cape town
# City number 14 of 627 complete. | Added bojnurd
# City number 15 of 627 complete. | Added ushuaia
# City number 16 of 627 complete. | Added tuktoyaktuk
# City number 17 of 627 complete. | Added thompson
# ...

# %%
#Create a dataframe with required items
city_data_df = pd.DataFrame({'City': city_name,
                            'Latitude': lat,
                            'Longitude': lng,
                            'Temperature': temp,
                            'Humidity': humid,
                            'Cloudiness': clouds,
                            'Wind Speed': wind})

#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# Out:
#            City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0       Iqaluit   63.7506   -68.5145        14.70        78         100
# 1        Albany   42.6001   -73.9662        35.83        70          15
# 2  Saint-Pierre  -21.3393    55.4781        80.60        55           0
# 3   Port Alfred  -33.5906    26.8910        63.54        47           0
# 4        Luanda   -8.8368    13.2343        75.20        94          75
#
#    Wind Speed
# 0       19.57
# 1        4.00
# 2        3.44
# 3        6.69
# 4        4.61

# %%
#Plot latitude vs temperature and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')
#this visualization shows the cities closest to the equator have higher temperatures."

# %%
#Plot latitude vs humidity and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'])
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig('lat_humid.png', bbox_inches='tight')
#this visualization shows a higher humidity in the Norhern Hemisphere."

# %%
#Plot latitude vs cloudiness and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'])
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig('lat_cloud.png', bbox_inches='tight')
#this visualization shows no correlation between the cloudiness of a city and it's latitude."

# %%
#Plot latitude vs wind speed and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'])
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')

#this visualiation shows most cities have a wind speed below 20 mph and the speed is not correlated to it's latitude."

# %%
# Calculate linear regression

north_hem_df = city_data_df.loc[city_data_df['Latitude']>0,:]
south_hem_df = city_data_df.loc[city_data_df['Latitude']<0,:]

#plot Northern Hemisphere vs Temp
x_values = north_hem_df['Latitude']
y_values = north_hem_df['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title('Northern Hemisphere vs Temperature')
plt.show()

# %%
#plot Southern Hemisphere vs Temp
x_values = south_hem_df['Latitude']
y_values = south_hem_df['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title('Southern Hemisphere vs Temperature')
plt.show()

# %%
#plot Northern Hemisphere vs Humidity
x_values = north_hem_df['Latitude']
y_values = north_hem_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('Northern Hemisphere vs Humidity')
plt.show()

# %%
#plot Southern Hemisphere vs Humidity
x_values = south_hem_df['Latitude']
y_values = south_hem_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('Southern Hemisphere vs Humidity')
plt.show()

# %%
#plot Northern Hemisphere vs Cloudiness
x_values = north_hem_df['Latitude']
y_values = north_hem_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('Northern Hemisphere vs Cloudiness')
plt.show()

# %%
#plot Southern Hemisphere vs Cloudiness
x_values = south_hem_df['Latitude']
y_values = south_hem_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('Southern Hemisphere vs Cloudiness')
plt.show()

# %%
#plot Northern Hemisphere vs Wind Speed
x_values = north_hem_df['Latitude']
y_values = north_hem_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title('Northern Hemisphere vs Wind Speed')
plt.show()

# %%
#plot Southern Hemisphere vs Wind Speed
x_values = south_hem_df['Latitude']
y_values = south_hem_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title('Southern Hemisphere vs Wind Speed')
plt.show()
